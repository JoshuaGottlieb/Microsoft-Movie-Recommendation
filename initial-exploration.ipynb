# %%
import pandas as pd
import sqlite3 as sql

# Studios and gross revenue - 3387 rows
# https://www.boxofficemojo.com/
gross_df = pd.read_csv('zippedData/bom.movie_gross.csv')
# The movie database - https://www.themoviedb.org/?language=en-US
# Reviews - 26517 rows, release date, popularity score, votes?
reviews_df = pd.read_csv('zippedData/tmdb.movies.csv')
# Budget and gross revenues - 5782 rows
# https://www.the-numbers.com/
budget_df = pd.read_csv('zippedData/tn.movie_budgets.csv')
# Movie ratings (R, etc.), genre, director, writer, theater/dvd date, length, box office amount, studio - 1560 rows
movie_info_df = pd.read_csv('zippedData/rt.movie_info.tsv', sep='\t')
# Rotten tomatoes - reviews, crtiic, review rating, critic quality - 54,432 rows
rt_reviews_df = pd.read_csv('zippedData/rt.reviews.tsv', sep='\t', encoding='latin-1')

conn = sql.connect('zippedData/im.db')
pd.read_sql("""
SELECT *
FROM movie_akas
""", conn)

# i dont know why it says operational error
# Out:
#          movie_id  ordering                                    title region  \
# 0       tt0369610        10                            Джурасик свят     BG
# 1       tt0369610        11                        Jurashikku warudo     JP
# 2       tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3       tt0369610        13                  O Mundo dos Dinossauros     BR
# 4       tt0369610        14                           Jurassic World     FR
# ...           ...       ...                                      ...    ...
# 331698  tt9827784         2                       Sayonara kuchibiru   None
# 331699  tt9827784         3                            Farewell Song    XWW
# 331700  tt9880178         1                              La atención   None
# 331701  tt9880178         2                              La atención     ES
# 331702  tt9880178         3                            The Attention    XWW
#
# ...

# %%
gross_df
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
budget_df
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...

# %%
# merging budget dataframe and gross dataframe by domestic gross, kept all the available titles from the budget_df since it contains more movies
merged_budget_and_gross = pd.merge(budget_df, gross_df, how = "left", on = "domestic_gross" )
merged_budget_and_gross.info()
merged_budget_and_gross
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6427 entries, 0 to 6426
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          6427 non-null   int64
#  1   release_date                6427 non-null   object
#  2   movie                       6427 non-null   object
#  3   production_budget           6427 non-null   float64
#  4   domestic_gross              6427 non-null   float64
#  5   worldwide_gross             6427 non-null   float64
#  6   profit_wwgross-prod_budget  6427 non-null   float64
#  7   title                       812 non-null    object
#  8   studio                      812 non-null    object
#  9   foreign_gross               539 non-null    object
#  10  year                        812 non-null    float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 602.5+ KB
# ...

# %% [markdown]
# Cleaned budget_df to turn all the monetary strings into ints so we can actually run calculations and or aggregations on it

# %%
budget_df[budget_df.columns[3:]] = budget_df[budget_df.columns[3:]].replace('[\$]|,', '', regex=True).astype(float)

# %% [markdown]
# Added column of world wide gross - production budget to get the profit margin
# Just call this column Net Profit so it's not too long

# %%
budget_df['profit_wwgross-prod_budget'] = budget_df['worldwide_gross']-budget_df['production_budget']

# %%
budget_df
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross  \
# 0           425000000.0     760507625.0     2.776345e+09
# ...

# %%
reviews_df
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# ...

# %%
movie_info_df
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                                                NaN     NR
# ...    ...                                                ...    ...
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# ...

# %%
rt_reviews_df
# Out:
#          id                                             review rating   fresh  \
# 0         3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1         3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2         3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3         3  Continuing along a line introduced in last yea...    NaN   fresh
# 4         3             ... a perverse twist on neorealism...     NaN   fresh
# ...     ...                                                ...    ...     ...
# 54427  2000  The real charm of this trifle is the deadpan c...    NaN   fresh
# 54428  2000                                                NaN    1/5  rotten
# 54429  2000                                                NaN    2/5  rotten
# 54430  2000                                                NaN  2.5/5  rotten
# 54431  2000                                                NaN    3/5   fresh
#
# ...

# %% [markdown]
# Joined movie basics, ratings, directors, and persons mainly to look at the ratings by genres and directors

# %%
director_and_ratings = pd.read_sql("""
SELECT DISTINCT b.*, r.averagerating, r.numvotes, p.primary_name AS 'director', p.primary_profession
FROM movie_basics b
JOIN movie_ratings r
ON b.movie_id = r.movie_id
LEFT JOIN directors d
ON b.movie_id = d.movie_id
LEFT JOIN persons p
ON d.person_id = p.person_id

""", conn)

# %%
director_and_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86777 entries, 0 to 86776
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   movie_id            86777 non-null  object
#  1   primary_title       86777 non-null  object
#  2   original_title      86777 non-null  object
#  3   start_year          86777 non-null  int64
#  4   runtime_minutes     77582 non-null  float64
#  5   genres              85838 non-null  object
#  6   averagerating       86777 non-null  float64
#  7   numvotes            86777 non-null  int64
#  8   director            86024 non-null  object
#  9   primary_profession  85935 non-null  object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 6.6+ MB

# %% [markdown]
# Top 25 Genres by average rating and means for runtimes and number of votes

# %%
director_and_ratings[['genres','runtime_minutes', 'averagerating','numvotes']].groupby('genres').mean().sort_values(by='averagerating', ascending = False).head(25)
# Out:
#                               runtime_minutes  averagerating    numvotes
# genres
# Comedy,Documentary,Fantasy              70.00       9.400000    5.000000
# Documentary,Family,Musical              59.00       9.300000   19.000000
# History,Sport                             NaN       9.200000    5.000000
# Game-Show                              130.00       9.000000    7.000000
# Music,Mystery                             NaN       9.000000    5.000000
# Drama,Fantasy,War                         NaN       8.800000   22.000000
# Documentary,News,Reality-TV             61.00       8.800000    8.000000
# Documentary,News,Sport                  85.00       8.800000   25.000000
# Comedy,Drama,Reality-TV                   NaN       8.800000   15.000000
# Drama,Short                             18.00       8.800000    8.000000
# Action,Adventure,Musical                97.00       8.700000   42.000000
# Adventure,Crime                        100.00       8.500000   15.000000
# ...

# %% [markdown]
# Top 25 Directors by average rating and means for runtimes and number of votes

# %%
director_and_ratings[['director','runtime_minutes', 'averagerating','numvotes']].groupby('director').mean().sort_values(by='averagerating', ascending = False).head(25)
# Out:
#                           runtime_minutes  averagerating  numvotes
# director
# Loreto Di Cesare                     70.0           10.0       8.0
# Lindsay Thompson                     65.0           10.0       7.0
# Masahiro Hayakawa                    59.0           10.0       5.0
# Chad Carpenter                        NaN           10.0       5.0
# Michiel Brongers                     48.0           10.0       5.0
# Emre Oran                            77.0           10.0       6.0
# Stephen Peek                          NaN           10.0      20.0
# Tristan David Luciotti                NaN           10.0       6.0
# Ivana Diniz                          52.0           10.0       5.0
# Andrew Jezard                        87.0            9.9       8.0
# Raphael Sbarge                       56.0            9.9       8.0
# Nagaraja Uppunda                    138.0            9.9     417.0
# Amoghavarsha                         53.0            9.9      10.0
# ...

# %%
writer = pd.read_sql("""
SELECT DISTINCT b.*, r.averagerating, r.numvotes, p.primary_name AS 'writer', p.primary_profession
FROM movie_basics b
JOIN movie_ratings r
ON b.movie_id = r.movie_id
LEFT JOIN writers w
ON b.movie_id = w.movie_id
LEFT JOIN persons p
ON w.person_id = p.person_id

""", conn)

# %% [markdown]
# Top 25 Writers by average rating and means for runtimes and number of votes

# %%
writer[['writer','runtime_minutes', 'averagerating','numvotes']].groupby('writer').mean().sort_values(by='averagerating', ascending = False).head(25)
# Out:
#                           runtime_minutes  averagerating  numvotes
# writer
# Emre Oran                            77.0           10.0       6.0
# Ana Beatriz Nogueira                 52.0           10.0       5.0
# Brian Baucum                         70.0           10.0       8.0
# Ivana Diniz                          52.0           10.0       5.0
# Lindsay Thompson                     65.0           10.0       7.0
# Cristina Duarte                      93.0           10.0       5.0
# Heather Augustyn                     99.0           10.0       5.0
# Loreto Di Cesare                     70.0           10.0       8.0
# Daniel Alexander                    100.0           10.0       5.0
# Bonnie Hawthorne                     77.0            9.8       6.0
# Fujisaki Ryuta                       54.0            9.8       5.0
# Javi Larrauri                        82.0            9.8       5.0
# Rok Andres                           55.0            9.8       5.0
# ...

# %%
pd.read_sql("""
SELECT *
FROM movie_basics m
JOIN principals pr
ON pr.movie_id = m.movie_id
JOIN known_for k
ON m.movie_id = k.movie_id
JOIN persons p
on p.person_id = k.person_id
""", conn)
# Out:
#           movie_id                   primary_title  \
# 0        tt0063540                       Sunghursh
# 1        tt0063540                       Sunghursh
# 2        tt0063540                       Sunghursh
# 3        tt0063540                       Sunghursh
# 4        tt0063540                       Sunghursh
# ...            ...                             ...
# 6857483  tt9916754  Chico Albuquerque - Revelações
# 6857484  tt9916754  Chico Albuquerque - Revelações
# 6857485  tt9916754  Chico Albuquerque - Revelações
# 6857486  tt9916754  Chico Albuquerque - Revelações
# 6857487  tt9916754  Chico Albuquerque - Revelações
#
#                          original_title  start_year  runtime_minutes  \
# 0                             Sunghursh        2013            175.0
# 1                             Sunghursh        2013            175.0
# 2                             Sunghursh        2013            175.0
# 3                             Sunghursh        2013            175.0
# ...
