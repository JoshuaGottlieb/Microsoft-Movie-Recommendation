# %%
import pandas as pd
from ast import literal_eval

df = pd.read_csv('../zippedData/merged_data.csv')
df2 = pd.read_parquet('../zippedData/merged_data.parquet')
df2.explode('writer')
# Out:
#                       title          ROI     profit  prod_budget  dom_gross  \
# 0                10 000 b c   156.253027  164065678    105000000   94784201
# 1       10 cloverfield lane  2065.728440  103286422      5000000   72082999
# 1       10 cloverfield lane  2065.728440  103286422      5000000   72082999
# 1       10 cloverfield lane  2065.728440  103286422      5000000   72082999
# 2     10 days in a madhouse   -99.878200  -11985384     12000000      14616
# ...                     ...          ...        ...          ...        ...
# 5694                   zulu   -88.473575  -14155772     16000000          0
# 5694                   zulu   -88.473575  -14155772     16000000          0
# 5695              zwartboek    23.810700    5238354     22000000    4398532
# 5696         ã l intã rieur   -70.135600   -2104068      3000000          0
# 5697            é æ ä è cj7   136.503855   27300771     20000000     206678
#
# ...

# %%
#df.genres = df.genres.apply(literal_eval)

# %%
#df.director.replace('[nan]', 'no director', inplace=True)

# %%
df.director = df.director.apply(literal_eval())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-fb87f476d613> in <module>
# ----> 1 df.director = df.director.apply(literal_eval())
#
# TypeError: literal_eval() missing 1 required positional argument: 'node_or_string'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-e38a2287ccb4> in <module>
# ----> 1 df.director.astype('list')
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5544         else:
#    5545             # else, only a single dtype is given
# -> 5546             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5547             return self._constructor(new_data).__finalize__(self, method="astype")
#    5548
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     593         self, dtype, copy: bool = False, errors: str = "raise"
#     594     ) -> "BlockManager":
# --> 595         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     596
#     597     def convert(
#
# ...
